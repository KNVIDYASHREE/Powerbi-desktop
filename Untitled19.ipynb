# %% [markdown]
# <a href="https://colab.research.google.com/github/KNVIDYASHREE/Powerbi-desktop/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# using install command of pip package
# !pip install -U pandas numpy sqlalchemy pydantic requests apache-airflow
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.3.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (1.4.54)
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.43-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (2.11.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.5)
# Requirement already satisfied: apache-airflow in /usr/local/lib/python3.12/dist-packages (3.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.8.3)
# Requirement already satisfied: apache-airflow-core==3.0.6 in /usr/local/lib/python3.12/dist-packages (from apache-airflow) (3.0.6)
# Requirement already satisfied: apache-airflow-task-sdk<1.1.0,>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from apache-airflow) (1.0.6)
# Requirement already satisfied: a2wsgi>=1.10.8 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.10.10)
# Requirement already satisfied: aiosqlite>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (0.21.0)
# Requirement already satisfied: alembic<2.0,>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.16.5)
# Requirement already satisfied: apache-airflow-providers-common-compat>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.7.3)
# Requirement already satisfied: apache-airflow-providers-common-io>=1.5.3 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.6.2)
# Requirement already satisfied: apache-airflow-providers-common-sql>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.27.5)
# Requirement already satisfied: apache-airflow-providers-smtp>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (2.2.0)
# Requirement already satisfied: apache-airflow-providers-standard>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.6.0)
# Requirement already satisfied: argcomplete>=1.10 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (3.6.2)
# Requirement already satisfied: asgiref>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (3.9.1)
# Requirement already satisfied: attrs!=25.2.0,>=22.1.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (25.3.0)
# Requirement already satisfied: cadwyn>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (5.4.4)
# Requirement already satisfied: colorlog>=6.8.2 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (6.9.0)
# Requirement already satisfied: cron-descriptor>=1.2.24 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (2.0.5)
# Requirement already satisfied: croniter>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (6.0.0)
# Requirement already satisfied: cryptography>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (43.0.3)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.2.18)
# Requirement already satisfied: dill>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (0.3.8)
# Requirement already satisfied: fastapi!=0.115.10,>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (0.116.1)
# Requirement already satisfied: flask>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (3.1.2)
# Requirement already satisfied: gunicorn>=20.1.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (23.0.0)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (0.28.1)
# Requirement already satisfied: importlib-metadata>=7.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (8.7.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (3.1.6)
# Requirement already satisfied: jsonschema>=4.19.1 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (4.25.1)
# Requirement already satisfied: lazy-object-proxy>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.12.0)
# Requirement already satisfied: libcst>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.8.2)
# Requirement already satisfied: linkify-it-py>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (2.0.3)
# Requirement already satisfied: lockfile>=0.12.2 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (0.12.2)
# Requirement already satisfied: methodtools>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (0.4.7)
# Requirement already satisfied: opentelemetry-api>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.36.0)
# Requirement already satisfied: opentelemetry-exporter-otlp>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.36.0)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (25.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (0.12.1)
# Requirement already satisfied: pendulum<4.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (3.1.0)
# Requirement already satisfied: pluggy>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.6.0)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (7.0.0)
# Requirement already satisfied: pygments!=2.19.0,>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (2.19.2)
# Requirement already satisfied: pyjwt>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (2.10.1)
# Requirement already satisfied: python-daemon>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (3.1.2)
# Requirement already satisfied: python-slugify>=5.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (8.0.4)
# Requirement already satisfied: rich-argparse>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.7.1)
# Requirement already satisfied: rich>=13.6.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (13.9.4)
# Requirement already satisfied: setproctitle>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.3.6)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (1.0.2)
# Requirement already satisfied: sqlalchemy-utils>=0.41.2 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (0.42.0)
# Requirement already satisfied: svcs>=25.1.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (25.1.0)
# Requirement already satisfied: tabulate>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (0.9.0)
# Requirement already satisfied: tenacity!=8.2.0,>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (8.5.0)
# Requirement already satisfied: termcolor>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (3.1.0)
# Requirement already satisfied: universal-pathlib!=0.2.4,>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (0.2.6)
# Requirement already satisfied: uuid6>=2024.7.10 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-core==3.0.6->apache-airflow) (2025.0.1)
# Requirement already satisfied: fsspec>=2023.10.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.6->apache-airflow) (2025.3.0)
# Requirement already satisfied: msgspec>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.6->apache-airflow) (0.19.0)
# Requirement already satisfied: retryhttp!=1.3.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.6->apache-airflow) (1.3.3)
# Requirement already satisfied: structlog>=25.4.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.6->apache-airflow) (25.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic<2.0,>=1.13.1->apache-airflow-core==3.0.6->apache-airflow) (1.1.3)
# Requirement already satisfied: sqlparse>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-providers-common-sql>=1.26.0->apache-airflow-core==3.0.6->apache-airflow) (0.5.3)
# Requirement already satisfied: more-itertools>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from apache-airflow-providers-common-sql>=1.26.0->apache-airflow-core==3.0.6->apache-airflow) (10.7.0)
# Requirement already satisfied: starlette>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from cadwyn>=5.2.1->apache-airflow-core==3.0.6->apache-airflow) (0.47.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=41.0.0->apache-airflow-core==3.0.6->apache-airflow) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated>=1.2.13->apache-airflow-core==3.0.6->apache-airflow) (1.17.3)
# Requirement already satisfied: fastapi-cli>=0.0.8 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (0.0.10)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (0.0.20)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (2.3.0)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (0.35.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask>=2.1.1->apache-airflow-core==3.0.6->apache-airflow) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask>=2.1.1->apache-airflow-core==3.0.6->apache-airflow) (8.2.1)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask>=2.1.1->apache-airflow-core==3.0.6->apache-airflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask>=2.1.1->apache-airflow-core==3.0.6->apache-airflow) (3.1.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.0->apache-airflow-core==3.0.6->apache-airflow) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.0->apache-airflow-core==3.0.6->apache-airflow) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.25.0->apache-airflow-core==3.0.6->apache-airflow) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=7.0->apache-airflow-core==3.0.6->apache-airflow) (3.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.1->apache-airflow-core==3.0.6->apache-airflow) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.1->apache-airflow-core==3.0.6->apache-airflow) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.1->apache-airflow-core==3.0.6->apache-airflow) (0.27.0)
# Requirement already satisfied: pyyaml>=5.2 in /usr/local/lib/python3.12/dist-packages (from libcst>=1.1.0->apache-airflow-core==3.0.6->apache-airflow) (6.0.2)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.12/dist-packages (from linkify-it-py>=2.0.0->apache-airflow-core==3.0.6->apache-airflow) (1.0.3)
# Requirement already satisfied: wirerope>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from methodtools>=0.4.7->apache-airflow-core==3.0.6->apache-airflow) (1.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.36.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.6->apache-airflow) (1.36.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.36.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.6->apache-airflow) (1.36.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.36.0->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.6->apache-airflow) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.36.0->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.6->apache-airflow) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.36.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.36.0->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.6->apache-airflow) (1.36.0)
# Requirement already satisfied: opentelemetry-proto==1.36.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.36.0->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.6->apache-airflow) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk~=1.36.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.36.0->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.6->apache-airflow) (1.36.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-proto==1.36.0->opentelemetry-exporter-otlp-proto-grpc==1.36.0->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.6->apache-airflow) (5.29.5)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify>=5.0->apache-airflow-core==3.0.6->apache-airflow) (1.3)
# Requirement already satisfied: types-requests in /usr/local/lib/python3.12/dist-packages (from retryhttp!=1.3.0,>=1.2.0->apache-airflow-task-sdk<1.1.0,>=1.0.6->apache-airflow) (2.32.4.20250809)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.6.0->apache-airflow-core==3.0.6->apache-airflow) (4.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=41.0.0->apache-airflow-core==3.0.6->apache-airflow) (2.22)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (2.7.0)
# Requirement already satisfied: typer>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (0.16.1)
# Requirement already satisfied: rich-toolkit>=0.14.8 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (0.15.0)
# Requirement already satisfied: fastapi-cloud-cli>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (0.1.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.6.0->apache-airflow-core==3.0.6->apache-airflow) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.25.0->apache-airflow-core==3.0.6->apache-airflow) (1.3.1)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (1.1.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (15.0.1)
# Requirement already satisfied: rignore>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (0.6.4)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (2.35.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk~=1.36.0->opentelemetry-exporter-otlp-proto-grpc==1.36.0->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.6->apache-airflow) (0.57b0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.6->apache-airflow) (1.5.4)

# %%
# import requests library
import requests

# API URL to fetch data from
url = '<a href="https://api.hevoexampleapi.com/data" target="_blank" rel="noreferrer noopener nofollow">https://api.hevoexampleapi.com/data</a>'

# Function that calls the API, fetches the data, and returns a JSON Object
def fetch_data_from_api(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"API request failed with status code {response.status_code}")

# %%
# importing pandas and numpy used for data transformation
import pandas as pd
import numpy as np

# Function definition for data transformation logic
def transform_data(df):
    # Example transformation: Fill missing values
    df.fillna(0, inplace=True)

    # Example transformation: Add a calculated column
    df['adjusted_value'] = df['value'] * np.log(df['quantity'] + 1)

    return df

# %%
# importing BaseModel from the pydantic package
from pydantic import BaseModel, ValidationError, conint

# Defining the data model based on the required data schema
class DataModel(BaseModel):
    name: str
    age: conint(gt=0)
    city: str

# Function definition for data validation across the data model.
def validate_data(data):
    try:
        return DataModel(**data)
    except ValidationError as e:
        print(e.json())
        return None

# %%
# importing create_engine function from sqlalchemy package
from sqlalchemy import create_engine

# function definition to write transformed data to the database
def store_data_in_db(df, connection_string, table_name):
    engine = create_engine(connection_string)
    df.to_sql(table_name, con=engine, if_exists='replace', index=False)

# %%
from airflow import DAG
from airflow.operators.python import PythonOperator
from datetime import datetime
import pandas as pd
import numpy as np
from pydantic import BaseModel, ValidationError, conint
from sqlalchemy import create_engine
import requests

# API URL to fetch data from
url = 'https://api.hevoexampleapi.com/data'

# Function that calls the API, fetches the data, and returns a JSON Object
def fetch_data_from_api(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"API request failed with status code {response.status_code}")

# Function definition for data transformation logic
def transform_data(df):
    # Example transformation: Fill missing values
    df.fillna(0, inplace=True)

    # Example transformation: Add a calculated column
    df['adjusted_value'] = df['value'] * np.log(df['quantity'] + 1)

    return df

# Defining the data model based on the required data schema
class DataModel(BaseModel):
    name: str
    age: conint(gt=0)
    city: str

# Function definition for data validation across the data model.
def validate_data(data):
    try:
        return DataModel(**data)
    except ValidationError as e:
        print(e.json())
        return None

# function definition to write transformed data to the database
def store_data_in_db(df, connection_string, table_name):
    engine = create_engine(connection_string)
    df.to_sql(table_name, con=engine, if_exists='replace', index=False)

# Default arguments for the DAG
default_args = {
    'owner': 'airflow',
    'depends_on_past': False,
    'start_date': datetime(2024, 9, 7),
    'retries': 1,
}

# Defining a DAG
dag = DAG(
    'simple_data_pipeline',
    default_args=default_args,
    description='A simple data pipeline using Airflow',
    schedule='@daily',
)

# Python operator for extraction task
extract_task = PythonOperator(
    task_id='extract',
    # Calling python function
    python_callable=fetch_data_from_api,
    dag=dag,
)

# Python operator for transform task
transform_task = PythonOperator(
    task_id='transform',
    # Calling Python function
    python_callable=transform_data,
    dag=dag,
)

# Python operator for data validation
validation_task = PythonOperator(
    task_id ='data-validation',
    # Calling Python function
    python_callable=validate_data,
    dag=dag
)

# Python operator for load task
load_task = PythonOperator(
    task_id='load',
    # Calling python function
    python_callable=store_data_in_db,
    dag=dag,
)

# Airflow task dependency
extract_task >> transform_task >> validation_task >> load_task
# Out:
# /tmp/ipython-input-1718492072.py:2 DeprecationWarning: The `airflow.operators.python.PythonOperator` class is deprecated. Please use `'airflow.providers.standard.operators.python.PythonOperator'`.
# <Task(PythonOperator): load>
